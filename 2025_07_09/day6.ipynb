# %%
1+2
# Out:
# 3

# %%
import csv
import json
import collections

# %%
from collections import defaultdict

# %%
import datetime as dt

dt.date(2025,7,9)
# Out:
# datetime.date(2025, 7, 9)

# %%
dt.datetime.strptime('2025-07-09', "%Y-%m-%d")
# Out:
# datetime.datetime(2025, 7, 9, 0, 0)

# %%
file_path = 'weather_data/sitka_weather_2021_simple-original.csv'

# import dataclasses

# @dataclasses
# class Weather:
#     station:str
#     name: str
#     date: dt.datetime
#     tavg: int
#     TMAX: int
#     TMIN: int



with open(file_path,'r') as f:
    reader = csv.DictReader(f)
    header = next(reader)
    print('header', header)
    result = defaultdict(list)
    for line in reader:
        # print(line.keys())
        result['STATION'].append(line['STATION'])
        result['NAME'].append(line['NAME'])
        d = dt.datetime.strptime(line['DATE'], "%Y-%m-%d")
        result['DATE'].append(d)
       # dt.datetime.strptime('2025-07-09', "%Y-%m-%d")
        result['TMAX'].append(float(line['TMAX']))
        result['TMIN'].append(float(line['TMIN']))
        # result.append((line['STATION'],line['NAME'],line['DATE'],float(line['TMAX']),float(line['TMIN'])))
    

result
# Out:
# header {'STATION': 'USW00025333', 'NAME': 'SITKA AIRPORT, AK US', 'DATE': '2021-01-01', 'TAVG': '', 'TMAX': '44', 'TMIN': '40'}
# defaultdict(list,
#             {'STATION': ['USW00025333',
#               'USW00025333',
#               'USW00025333',
#               'USW00025333',
#               'USW00025333',
#               'USW00025333',
#               'USW00025333',
#               'USW00025333',
#               'USW00025333',
#               'USW00025333',
#               'USW00025333',
#               'USW00025333',
#               'USW00025333',
#               'USW00025333',
#               'USW00025333',
#               'USW00025333',
#               'USW00025333',
#               'USW00025333',
#               'USW00025333',
#               'USW00025333',
#               'USW00025333',
#               'USW00025333',
#               'USW00025333',
#               'USW00025333',
#               'USW00025333',
#               'USW00025333',
#               'USW00025333',
# ...

# %%
result['DATE']
# Out:
# [datetime.datetime(2021, 1, 2, 0, 0),
#  datetime.datetime(2021, 1, 3, 0, 0),
#  datetime.datetime(2021, 1, 4, 0, 0),
#  datetime.datetime(2021, 1, 5, 0, 0),
#  datetime.datetime(2021, 1, 6, 0, 0),
#  datetime.datetime(2021, 1, 7, 0, 0),
#  datetime.datetime(2021, 1, 8, 0, 0),
#  datetime.datetime(2021, 1, 9, 0, 0),
#  datetime.datetime(2021, 1, 10, 0, 0),
#  datetime.datetime(2021, 1, 11, 0, 0),
#  datetime.datetime(2021, 1, 12, 0, 0),
#  datetime.datetime(2021, 1, 13, 0, 0),
#  datetime.datetime(2021, 1, 14, 0, 0),
#  datetime.datetime(2021, 1, 15, 0, 0),
#  datetime.datetime(2021, 1, 16, 0, 0),
#  datetime.datetime(2021, 1, 17, 0, 0),
#  datetime.datetime(2021, 1, 18, 0, 0),
#  datetime.datetime(2021, 1, 19, 0, 0),
#  datetime.datetime(2021, 1, 20, 0, 0),
#  datetime.datetime(2021, 1, 21, 0, 0),
#  datetime.datetime(2021, 1, 22, 0, 0),
#  datetime.datetime(2021, 1, 23, 0, 0),
#  datetime.datetime(2021, 1, 24, 0, 0),
#  datetime.datetime(2021, 1, 25, 0, 0),
# ...

# %%
[r[3] for r in result]
# Out:
# [44.0,
#  43.0,
#  45.0,
#  45.0,
#  44.0,
#  48.0,
#  48.0,
#  46.0,
#  46.0,
#  44.0,
#  44.0,
#  39.0,
#  47.0,
#  48.0,
#  47.0,
#  46.0,
#  48.0,
#  42.0,
#  38.0,
#  41.0,
#  40.0,
#  38.0,
#  39.0,
#  37.0,
#  36.0,
#  30.0,
#  36.0,
#  40.0,
#  42.0,
#  43.0,
#  38.0,
#  38.0,
#  40.0,
#  39.0,
#  37.0,
#  37.0,
#  36.0,
#  30.0,
#  17.0,
#  30.0,
#  37.0,
#  39.0,
#  38.0,
#  37.0,
#  35.0,
#  38.0,
#  43.0,
#  43.0,
#  42.0,
#  44.0,
#  44.0,
#  42.0,
#  38.0,
#  39.0,
#  42.0,
#  43.0,
#  44.0,
#  45.0,
#  41.0,
#  41.0,
#  41.0,
#  43.0,
#  43.0,
#  43.0,
#  47.0,
#  40.0,
#  41.0,
#  40.0,
#  41.0,
#  37.0,
#  35.0,
#  34.0,
#  40.0,
#  42.0,
#  43.0,
#  40.0,
#  37.0,
#  39.0,
#  43.0,
#  42.0,
#  42.0,
#  40.0,
#  41.0,
#  42.0,
#  39.0,
#  41.0,
#  41.0,
#  41.0,
#  41.0,
#  36.0,
#  38.0,
#  41.0,
#  41.0,
#  40.0,
#  38.0,
#  41.0,
#  39.0,
#  39.0,
#  36.0,
#  41.0,
#  41.0,
#  45.0,
#  45.0,
#  48.0,
#  50.0,
#  56.0,
#  67.0,
#  61.0,
#  51.0,
#  57.0,
#  52.0]

# %%
import matplotlib.pyplot as plt


plt.plot(range(len(result)),[r[3] for r in result])

# %%
import matplotlib.pyplot as plt


plt.plot(result['DATE'],result['TMAX'])

# %%
import pandas as pd

# %%
df = pd.read_csv(file_path)
df.head()
# Out:
#        STATION                  NAME        DATE  TAVG  TMAX  TMIN
# 0  USW00025333  SITKA AIRPORT, AK US  2021-01-01   NaN  44.0    40
# 1  USW00025333  SITKA AIRPORT, AK US  2021-01-02   NaN  44.0    35
# 2  USW00025333  SITKA AIRPORT, AK US  2021-01-03   NaN  43.0    36
# 3  USW00025333  SITKA AIRPORT, AK US  2021-01-04   NaN  45.0    39
# 4  USW00025333  SITKA AIRPORT, AK US  2021-01-05   NaN  45.0    40

# %%
plt.plot(df['TMAX'])

# %%
from pathlib import Path
import csv

path = Path('weather_data/sitka_weather_07-2021_simple.csv')
lines = path.read_text().splitlines()

reader = csv.reader(lines)
header_row = next(reader)
print(header_row)

for index, column_header in enumerate(header_row):
    print(index, column_header)
# Out:
# ['STATION', 'NAME', 'DATE', 'TAVG', 'TMAX', 'TMIN']
# 0 STATION
# 1 NAME
# 2 DATE
# 3 TAVG
# 4 TMAX
# 5 TMIN

# %%
import matplotlib.pyplot as plt
from datetime import datetime

#최고 기온을 추출합니다

dates, highs = [], []
for row in reader:
    current_date = datetime.strptime(row[2], '%Y-%m-%d')
    high = int(row[4])
    dates.append(current_date)
    highs.append(high)
print(highs)
# Out:
# []

# %%
# plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.plot(dates, highs, color='red')

# %%
import csv
file_path = 'weather_data/sitka_weather_2021_simple-original.csv'

with open(file_path,'r') as f:
    reader = csv.DictReader(f)
    header = next(reader)
    print('header', header)
# Out:
# header {'STATION': 'USW00025333', 'NAME': 'SITKA AIRPORT, AK US', 'DATE': '2021-01-01', 'TAVG': '', 'TMAX': '44', 'TMIN': '40'}

# %%
import datetime as dt

data = {'STATION': 'USW00025333', 
        'NAME': 'SITKA AIRPORT, AK US', 
        'DATE': str(dt.datetime(2021,1,1)), 
        'TAVG': '', 
        'TMAX': '44', 
        'TMIN': '40'}

# %%
str(dt.datetime(2021,1,1))
# Out:
# '2021-01-01 00:00:00'

# %%
import json

with open('weather.json','w') as f:
    json.dump(data,f)

# %%
with open('weather.json','r') as f:
    data2 = json.load(f)
data2
# Out:
# {'STATION': 'USW00025333',
#  'NAME': 'SITKA AIRPORT, AK US',
#  'DATE': '2021-01-01 00:00:00',
#  'TAVG': '',
#  'TMAX': '44',
#  'TMIN': '40'}

# %%
dumpted_data = json.dumps(data)
type(dumpted_data)
# Out:
# str

# %%
json.loads(dumpted_data)
# Out:
# {'STATION': 'USW00025333',
#  'NAME': 'SITKA AIRPORT, AK US',
#  'DATE': '2021-01-01 00:00:00',
#  'TAVG': '',
#  'TMAX': '44',
#  'TMIN': '40'}

# %%
data2['DATE'] = dt.datetime.strftime(data2['DATE'], '%Y-%m-%d')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 data2['DATE'] = dt.datetime.strftime(data2['DATE'], '%Y-%m-%d')
#
# TypeError: descriptor 'strftime' for 'datetime.date' objects doesn't apply to a 'str' object

# %%
import json

# %%
file_path = 'eq_data/eq_data_1_day_m1.geojson'
with open(file_path,'r',encoding='utf-8') as f:
    data = json.load(f)
data
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1649052296000,
#   'url': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_day.geojson',
#   'title': 'USGS Magnitude 1.0+ Earthquakes, Past Day',
#   'status': 200,
#   'api': '1.10.3',
#   'count': 160},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 1.6,
#     'place': '27 km NNW of Susitna, Alaska',
#     'time': 1649051836769,
#     'updated': 1649052020437,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0224bju1jx',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0224bju1jx.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 39,
#     'net': 'ak',
#     'code': '0224bju1jx',
#     'ids': ',ak0224bju1jx,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.54,
# ...

# %%
data.keys()
# Out:
# dict_keys(['type', 'metadata', 'features', 'bbox'])

# %%
type(data['features']), len(data['features'])
# Out:
# (list, 160)

# %%
data['bbox']
# Out:
# [-173.0821, -57.4218, -0.6, 170.0847, 65.7868, 201.27]

# %%
data['features'][0].keys()
# Out:
# dict_keys(['type', 'properties', 'geometry', 'id'])

# %%
data['features'][0]['properties']
# Out:
# {'mag': 1.6,
#  'place': '27 km NNW of Susitna, Alaska',
#  'time': 1649051836769,
#  'updated': 1649052020437,
#  'tz': None,
#  'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0224bju1jx',
#  'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak0224bju1jx.geojson',
#  'felt': None,
#  'cdi': None,
#  'mmi': None,
#  'alert': None,
#  'status': 'automatic',
#  'tsunami': 0,
#  'sig': 39,
#  'net': 'ak',
#  'code': '0224bju1jx',
#  'ids': ',ak0224bju1jx,',
#  'sources': ',ak,',
#  'types': ',origin,phase-data,',
#  'nst': None,
#  'dmin': None,
#  'rms': 0.54,
#  'gap': None,
#  'magType': 'ml',
#  'type': 'earthquake',
#  'title': 'M 1.6 - 27 km NNW of Susitna, Alaska'}

# %%
data['features'][0]['geometry']
# Out:
# {'type': 'Point', 'coordinates': [-150.7585, 61.7591, 56.3]}

# %%
data['features'][0]['id']
# Out:
# 'ak0224bju1jx'

# %%
file_path = 'eq_data/eq_data_1_day_m1.geojson'
with open(file_path,'r',encoding='utf-8') as f:
    data = json.load(f)
    mags = []
    lons = []
    lats = []

    mags = {}
    lons = {}
    lats = {}

    result = defaultdict(list)
    
    for f in data['features']:
        print('mag', f['properties']['mag'])
        print('lon', f['geometry']['coordinates'][0])
        print('lat', f['geometry']['coordinates'][1])
        break
# Out:
# mag 1.6
# lon -150.7585
# lat 61.7591

# %%
path = Path('eq_data/eq_data_1_day_m1.geojson')
contents = path.read_text(encoding='utf-8')
all_eq_data = json.loads(contents)


path = Path('eq_data/readable_eq_data.geojson')
readable_contents = json.dumps(all_eq_data,indent=4)
path.write_text(readable_contents)
# Out:
# 223652

# %%
import plotly.express as px
from pathlib import Path
import json

path = Path('eq_data/eq_data_1_day_m1.geojson')
contents = path.read_text(encoding='utf-8')
all_eq_data = json.loads(contents)

all_eq_dicts = all_eq_data['features']
print(len(all_eq_dicts))

mags, lons, lats = [], [], []
for eq_dict in all_eq_dicts:
    mag = eq_dict['properties']['mag']
    lon = eq_dict['geometry']['coordinates'][0]
    lat = eq_dict['geometry']['coordinates'][1]
    
    mags.append(mag)
    lons.append(lon)
    lats.append(lat)

title = 'Global Earthquakes'
fig = px.scatter_geo(lat=lats, lon=lons, title=title)
fig.show()
# Out:
# 160

# %%
import plotly.express as px
from pathlib import Path
import json

path = Path('eq_data/eq_data_1_day_m1.geojson')
contents = path.read_text(encoding='utf-8')
all_eq_data = json.loads(contents)

all_eq_dicts = all_eq_data['features']
print(len(all_eq_dicts))

mags, lons, lats = {}, {}, {}
for eq_dict in all_eq_dicts:
    mag = eq_dict['properties']['mag']
    lon = eq_dict['geometry']['coordinates'][0]
    lat = eq_dict['geometry']['coordinates'][1]
    
    mags.append(mag)
    lons.append(lon)
    lats.append(lat)

title = 'Global Earthquakes'
fig = px.scatter_geo(lat=lats, lon=lons, title=title)
fig.show()

# %%
import plotly.express as px

    title = 'Global Earthquakes'
    fig = px.scatter_geo(lat=lats, lon=lons, title=title)
    fig.show()
# Out:
#   Cell In[129], line 3
#     title = 'Global Earthquakes'
#     ^
# IndentationError: unexpected indent

# %%
pip install nbformat --upgrade
# Out:
# ...
#      ---------------------------------------- 78.5/78.5 KB 4.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 88.7/88.7 KB 5.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 231.6/231.6 KB 7.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 63.8/63.8 KB 3.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 25.1.1 is available.
# You should consider upgrading via the 'c:\Users\user\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
